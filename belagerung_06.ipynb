# %% [raw]
# ---
# title: "Belagerungsszene VI: Belagerung der Festung von Visegrád"
# jupyter: python3
# code-fold: true
# execute:
#   echo: true
#   output: asis
#
# ---

# %%
from funktionen import *

# %%
get_text("Q257")
#Belagerung VI

get_img("Q243")
#Festung Visegrád
# Out:
# Wikibase link: [https://computational-publishing-service.wikibase.cloud/entity/Q257](https://computational-publishing-service.wikibase.cloud/entity/Q257)
#
# Kurator: Seeger, Ulrike
#
#
# <head>
#   <meta charset="utf-8" />
#   <meta content="text" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# </head>
# <html xmlns="http://www.w3.org/1999/xhtml" lang="de" xml:lang="de">
#   <body>
#     <h3>Belagerung VI: "Vestung Vizzegrad wie die von Christen belegert gewesen Anno 1595“</h3>
#     <p>
# ...
