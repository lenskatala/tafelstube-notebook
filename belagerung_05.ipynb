# %% [raw]
# ---
# title: "Belagerungsszene V: Eroberung der Festung Gran"
# jupyter: python3
# code-fold: true
# execute:
#   echo: true
#   output: asis
#
# ---

# %%
from funktionen import *

# %%
get_text("Q256")
#Belagerung V

get_img("Q242")
#Festung Gran
# Out:
# Wikibase link: [https://computational-publishing-service.wikibase.cloud/entity/Q256](https://computational-publishing-service.wikibase.cloud/entity/Q256)
#
# Kurator: Seeger, Ulrike
#
#
# <head>
#   <meta charset="utf-8" />
#   <meta content="text" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# </head>
# <html xmlns="http://www.w3.org/1999/xhtml" lang="de" xml:lang="de">
#   <body>
#     <h3>Belagerung V: „Vestung Gran wie die von den Christen wider erobert worden. A&#091;nn&#093;o 1595.“</h3>
#     <p>
# ...
