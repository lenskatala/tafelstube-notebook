# %% [raw]
# ---
# title: "Belagerungsszene VII: Belagerung der Stadt Waitzen"
# jupyter: python3
# code-fold: true
# execute:
#   echo: true
#   output: asis
#
# ---

# %%
from funktionen import *

# %%
get_text("Q258")
#Belagerung VII

get_img("Q244")
#Stadt Waitzen
# Out:
# Wikibase link: [https://computational-publishing-service.wikibase.cloud/entity/Q258](https://computational-publishing-service.wikibase.cloud/entity/Q258)
#
# Kurator: Seeger, Ulrike
#
#
# <head>
#   <meta charset="utf-8" />
#   <meta content="text" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# </head>
# <html xmlns="http://www.w3.org/1999/xhtml" lang="de" xml:lang="de">
#   <body>
#     <h3>Belagerung VII: „Statt Waitzen wie die von vom T&uuml;rcken belegert gewesen 1597“
#     </h3>
#     <p>
# ...
