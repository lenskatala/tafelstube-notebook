# %% [raw]
# ---
# title: "Belagerungsszene XII: Scharmützel bei der Belagerung der Stadt Ofen 1603"
# jupyter: python3
# code-fold: true
# execute:
#   echo: true
#   output: asis
#
# ---

# %%
from funktionen import *

# %%
get_text("Q263")
#Belagerung XII

get_img("Q249")
#Scharmützel Ofen 1603
# Out:
# Wikibase link: [https://computational-publishing-service.wikibase.cloud/entity/Q263](https://computational-publishing-service.wikibase.cloud/entity/Q263)
#
# Kurator: Seeger, Ulrike
#
#
#
#
#
#
#
#
#
# ### Belagerung XII: „Vestung Gran wie die vom Türcken belegert gewesen A\[nn]o 1604“
#
#
#
# ...
