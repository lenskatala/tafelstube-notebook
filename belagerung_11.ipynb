# %% [raw]
# ---
# title: "Belagerungsszene XI: Belagerung der Festung Gran 1604"
# jupyter: python3
# code-fold: true
# execute:
#   echo: true
#   output: asis
#
# ---

# %%
from funktionen import *

# %%
get_text("Q262")
#Belagerung XI

get_img("Q248")
#Belagerung Gran 1604
# Out:
# Wikibase link: [https://computational-publishing-service.wikibase.cloud/entity/Q262](https://computational-publishing-service.wikibase.cloud/entity/Q262)
#
# Kurator: Seeger, Ulrike
#
#
# <head>
#   <meta charset="utf-8" />
#   <meta content="text" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# </head>
# <html xmlns="http://www.w3.org/1999/xhtml" lang="de" xml:lang="de">
#   <body>
#     <h3>Belagerung XI: „Hauptstatt Offen, wie die von Christn belegert gewesen, ein Sch&auml;rm&uuml;tzell. darbei geschehen. 1603“</h3>
#     <p>
# ...
